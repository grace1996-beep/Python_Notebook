# %% [markdown]
# importing pandas liblary

# %%
import pandas as pd

# %% [markdown]
# loading datasets and doing cleaning before merging

# %%
#first loading my celll_geo csv file
df=pd.read_csv("cells_geo.csv",delimiter=",")
df.rename(columns={"CDELL_ID":"CELL_ID"},inplace=True)
df.rename(columns={"VILLES":"CITY"},inplace=True)
df.rename(columns={"SITE_CODE":"SITE_ID"},inplace=True)
df
# Out:
#       Unnamed: 0      CITY      STATUS LOCALISATION     DECOUPZON  \
# 0              0    ADJAME  In Service      ABIDJAN  "Abidjan_EST
# 1              1    ADJAME  In Service      ABIDJAN  "Abidjan_EST
# 2              2    ADJAME  In Service      ABIDJAN  "Abidjan_EST
# 3              3   ASSINIE  In Service    INTERIEUR     Grand-EST
# 4              4   ASSINIE  In Service    INTERIEUR     Grand-EST
# ...          ...       ...         ...          ...           ...
# 3969        3969  ZUENOULA  In Service    INTERIEUR    Grand-NORD
# 3970        3970  ZUENOULA  In Service    INTERIEUR    Grand-NORD
# 3971        3971  ZUENOULA  In Service    INTERIEUR    Grand-NORD
# 3972        3972  ZUENOULA  In Service    INTERIEUR    Grand-NORD
# 3973        3973  ZUENOULA  In Service    INTERIEUR    Grand-NORD
#
#                  ZONENAME  LONGITUDE  LATITUDE     REGION          AREA  \
# 0                AGBANNEW  -4.000667  5.368194     LAGUNE           NaN
# ...

# %%
#droping duplicates
df1=df.drop_duplicates()
#deleting rows with no data at all
dfna=df1.dropna(how='all')
#delete missing values in dataframe
df_final=dfna.dropna()
df_final
# Out:
#       Unnamed: 0      CITY      STATUS LOCALISATION     DECOUPZON  \
# 23            23     ABOBO  In Service      ABIDJAN  Abidjan_NORD
# 24            24     ABOBO  In Service      ABIDJAN  Abidjan_NORD
# 25            25     ABOBO  In Service      ABIDJAN  Abidjan_NORD
# 26            26     ABOBO  In Service      ABIDJAN  Abidjan_NORD
# 27            27     ABOBO  In Service      ABIDJAN  Abidjan_NORD
# ...          ...       ...         ...          ...           ...
# 3969        3969  ZUENOULA  In Service    INTERIEUR    Grand-NORD
# 3970        3970  ZUENOULA  In Service    INTERIEUR    Grand-NORD
# 3971        3971  ZUENOULA  In Service    INTERIEUR    Grand-NORD
# 3972        3972  ZUENOULA  In Service    INTERIEUR    Grand-NORD
# 3973        3973  ZUENOULA  In Service    INTERIEUR    Grand-NORD
#
#                    ZONENAME  LONGITUDE  LATITUDE    REGION           AREA  \
# 23    ZONE E - Abidjan_NORD  -4.014139  5.433500    LAGUNE  ABIDJAN NORTH
# ...

# %%
#loading the telcom datasets and renamimg some of the columns ie cleaning
df1=pd.read_csv("Telcom_dataset.csv")
#to rename the columns PRODUTC TO PRODUCT
df1.rename(columns={"PRODUTC":"PRODUCT"},inplace=True)
df1.rename(columns={"DATETIME":"DATE_TIME"},inplace=True)
#to cleandf1
#to drop duplicates
dfrr=df1.drop_duplicates()
#to remove missing values
dfr3=dfrr.dropna()
#deleterows without data
dfall1=dfr3.dropna(how='all')
df2=pd.read_csv("Telcom_dataset2.csv")
#to clean to drop duplicates
dfm=df2.drop_duplicates()
#to remove mising values
dd=dfm.dropna()
#to remove rows without data
dfall2=dd.dropna(how='all')
df2.rename(columns={"DW_A_NUMBER":"DW_A_NUMBER_INT"},inplace=True)
df2.rename(columns={"DW_B_NUMBER":"DW_B_NUMBER_INT"},inplace=True)
df3=pd.read_csv("Telcom_dataset3.csv")

df3.rename(columns={"CELLID":"CELL_ID"},inplace=True)
df3.rename(columns={"SIET_ID":"SITE_ID"},inplace=True)
#to remove duplicates
dl=df3.drop_duplicates()
#to remove missing values
dl2=dl.dropna()
#to remove empty rows
dfall3=dl2.dropna(how='all')
dfs=pd.concat((dfall1,dfall2,dfall3),axis=0,ignore_index=True)
dfs
# Out:
#       PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0       Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1         sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 2         sms     25  2012-05-06 23:05:41.0            0  6008887b0207d82
# 3       Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 4       Voice     14  2012-05-06 23:06:29.0            1  966ba4656e38e62
# ...       ...    ...                    ...          ...              ...
# 12784   Voice     10  2012-05-09 00:01:43.0            0  2f834987f0c1825
# 12785   Voice      0  2012-05-09 00:01:43.0            3  467333ade2b4b9c
# 12786   Voice     62  2012-05-09 00:01:43.0            1  e077a6b74c5053c
# 12787   Voice     30  2012-05-09 00:01:43.0            2  672ce74c418aa7a
# 12788   Voice     60  2012-05-09 00:01:43.0            2  6edeb4c55714650
#
#        DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID  \
# ...

# %% [markdown]
# creating my own questions to iterate through the columns

# %%
#first question. select value which is greater than 60
#selecting value that is greater than 60
#this means the highest billing price 
dfl=dfs.VALUE >=50
dfl.head()
dfs.loc[dfs.VALUE >=50]
# Out:
#       PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 3       Voice     56  2012-05-06 23:05:42.0            1  7370032e20f4e96
# 22        sms     50  2012-05-06 23:11:14.0            1  8ac7935e68f6ab3
# 30      Voice    192  2012-05-06 23:12:43.0            1  03dd5e41773fcf1
# 32      Voice     99  2012-05-06 23:13:03.0            2  b3944e04b20094c
# 41      Voice   1610  2012-05-06 23:14:03.0            1  b2b3dbfe5ce4bc1
# ...       ...    ...                    ...          ...              ...
# 12776   Voice    102  2012-05-09 00:01:43.0            5  4219dbbc5a883b3
# 12781   Voice    236  2012-05-09 00:01:43.0            2  00c06875b7dc2de
# 12782   Voice    219  2012-05-09 00:01:43.0            0  1fa5703aa7d59be
# 12786   Voice     62  2012-05-09 00:01:43.0            1  e077a6b74c5053c
# 12788   Voice     60  2012-05-09 00:01:43.0            2  6edeb4c55714650
#
#        DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID  \
# ...

# %%
#Question 2 selecting value that is less than ten
#the value<10
#this values have the lowest billing price
#will use this to show later products with value less than ten
dfl=dfs.VALUE <=10
dfl.head()
dfs.loc[dfs.VALUE <=10]
# Out:
#       PRODUCT  VALUE              DATE_TIME CELL_ON_SITE  DW_A_NUMBER_INT  \
# 0       Voice      0  2012-05-06 23:04:37.0            1  49fae048b547780
# 1         sms      0  2012-05-06 23:05:25.0            0  7a54a6eaee19e65
# 5        data      0  2012-05-06 23:07:26.0            _  f71825ca6e623f9
# 6       Voice      0  2012-05-06 23:08:02.0            1  4afd7d5af21b1ce
# 7       Voice      0  2012-05-06 23:08:03.0            5  d717dee81c51389
# ...       ...    ...                    ...          ...              ...
# 12777   Voice      0  2012-05-09 00:01:43.0            0  950fcba99c5fa62
# 12778   Voice      0  2012-05-09 00:01:43.0            4  461abdc8fe8c8fb
# 12779   Voice      1  2012-05-09 00:01:43.0            1  f8cff86f055ecb1
# 12784   Voice     10  2012-05-09 00:01:43.0            0  2f834987f0c1825
# 12785   Voice      0  2012-05-09 00:01:43.0            3  467333ade2b4b9c
#
#        DW_B_NUMBER_INT COUNTRY_A COUNTRY_B     CELL_ID     SITE_ID  \
# ...

# %%
#question 3
#selecting cell_id that had a billing price of more than 60
dfl=dfs.VALUE >=60
dfl.head()
dfs.loc[dfs.VALUE >=60,'CELL_ID']
# Out:
# 30       1AX75JmPtt
# 32       /u0FSD+ahi
# 41       47yB6si0R9
# 49       54Pb8dz/52
# 50       +38u2u/rfx
#             ...
# 12776    d5bdd4f4cb
# 12781    26c3cc23da
# 12782    34f124cb0d
# 12786    7f1f2f889f
# 12788    1c11a2fcbb
# Name: CELL_ID, Length: 1317, dtype: object

# %%
#question 4
#selecting the product with the great billing
#il select the products whose billing price is above 60
dfl=dfs.VALUE >=60
dfl.head()
dfs.loc[dfs.VALUE >=60,'PRODUCT']
# Out:
# 30       Voice
# 32       Voice
# 41       Voice
# 49       Voice
# 50       Voice
#          ...
# 12776    Voice
# 12781    Voice
# 12782    Voice
# 12786    Voice
# 12788    Voice
# Name: PRODUCT, Length: 1317, dtype: object

# %%
#question 5
#selecting the cell id that was least used
#this means this cell id had the lowest billing peice that is value <=10
dfl=dfs.VALUE <=10
dfl.head()
dfs.loc[dfs.VALUE<=10,'CELL_ID']
# Out:
# 0        /TJNe+Mmtu
# 1        /+cKZKIp41
# 5        /lrUXVGVcN
# 6        +38u2u/rfx
# 7        09UjmmY1Ds
#             ...
# 14990    ef7e987044
# 14991    63cb899693
# 14992    425d28ede5
# 14997    6467daa1db
# 14998    2aa04dcab7
# Name: CELL_ID, Length: 9662, dtype: object

# %%
#question 6
#selecting the site ids that were frequently used meaning they had the highest value
dfl=dfs.VALUE >=60
dfl.head()
dfs.loc[dfs.VALUE >=60,'SITE_ID']
# Out:
# 30       1AX75JmPtt
# 32       /u0FSD+ahi
# 41       47yB6si0R9
# 49       54Pb8dz/52
# 50       +38u2u/rfx
#             ...
# 12776    cdf82e4fe3
# 12781    d2de5847b1
# 12782    73dd78713b
# 12786    b4ddb9e93c
# 12788    6d70dae094
# Name: SITE_ID, Length: 1317, dtype: object
